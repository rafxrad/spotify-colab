# %% [markdown]
# <a href="https://colab.research.google.com/github/rafxrad/spotify-colab/blob/main/SpotifyData_KNN_ERF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
from google.colab import files
import requests
import numpy
import os

# %%
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
local_dir = '/content/gdrive/MyDrive/data'

# %% [markdown]
# Carregando todos os arquivos json.

# %%
json_files = [f for f in os.listdir(local_dir) if f.endswith(".json")]
print(json_files)
# Out:
# ['2020_4.json', '2019_3.json', '2018_1.json', '2016_0.json', 'Streaming_History_Audio_2023_10.json', '2023.json', 'Streaming_History_Audio_2021_6.json', 'Streaming_History_Audio_2018_2.json', '2023_8.json', '2022_7.json', '2021_5.json', 'Streaming_History_Audio_2023_9.json']

# %% [markdown]
# Transformando todas os arquivos em dataframe.

# %%
dfs = []
for file in json_files:
  df = pd.read_json('{}/{}'.format(local_dir,file))
  dfs.append(df)

# %% [markdown]
# Checando a estrutura das colunas antes de combiná-las.

# %%
for num, df in enumerate(dfs):
  print(f"index: {num}': 'df':{df.columns}")
# Out:
# index: 0': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')
# index: 1': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')
# index: 2': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')
# index: 3': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')
# index: 4': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')
# index: 5': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')
# index: 6': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')
# index: 7': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')
# index: 8': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')
# index: 9': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')
# index: 10': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')
# index: 11': 'df':Index(['ts', 'username', 'platform', 'ms_played', 'conn_country',
#        'ip_addr_decrypted', 'user_agent_decrypted',
#        'master_metadata_track_name', 'master_metadata_album_artist_name',
#        'master_metadata_album_album_name', 'spotify_track_uri', 'episode_name',
#        'episode_show_name', 'spotify_episode_uri', 'reason_start',
#        'reason_end', 'shuffle', 'skipped', 'offline', 'offline_timestamp',
#        'incognito_mode'],
#       dtype='object')

# %%
concat_dfs = pd.concat(dfs)
# Out:
# <ipython-input-79-027b1fd71aac>:1: FutureWarning: Behavior when concatenating bool-dtype and numeric-dtype arrays is deprecated; in a future version these will cast to object dtype (instead of coercing bools to numeric values). To retain the old behavior, explicitly cast bool-dtype arrays to numeric dtype.
#   concat_dfs = pd.concat(dfs)

# %%
concat_dfs
# Out:
# /usr/local/lib/python3.10/dist-packages/IPython/lib/pretty.py:700: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   output = repr(obj)
# /usr/local/lib/python3.10/dist-packages/google/colab/_interactive_table_hint_button.py:178: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_html=dataframe._repr_html_(),  # pylint: disable=protected-access
#                          ts    username                platform  ms_played  \
# 0      2019-11-11T11:10:00Z  1272745283  iOS 13.1.3 (iPhone9,3)      79644
# 1      2019-11-11T11:10:01Z  1272745283  iOS 13.1.3 (iPhone9,3)       1021
# 2      2019-11-11T11:10:03Z  1272745283  iOS 13.1.3 (iPhone9,3)        835
# 3      2019-11-11T11:10:06Z  1272745283  iOS 13.1.3 (iPhone9,3)       1904
# 4      2019-11-11T11:10:08Z  1272745283  iOS 13.1.3 (iPhone9,3)       1021
# ...                     ...         ...                     ...        ...
# 17139  2023-09-12T01:27:12Z  1272745283                     ios        810
# 17140  2023-09-12T01:27:20Z  1272745283                     ios       8149
# 17141  2023-09-12T01:27:26Z  1272745283                     ios       5866
# 17142  2023-09-12T01:27:44Z  1272745283                     ios      16490
# 17143  2023-09-12T01:27:49Z  1272745283                     ios       6101
#
#       conn_country ip_addr_decrypted user_agent_decrypted  \
# 0               BR    177.37.209.109              unknown
# 1               BR    177.37.209.109              unknown
# 2               BR    177.37.209.109              unknown
# 3               BR    177.37.209.109              unknown
# 4               BR    177.37.209.109              unknown
# ...            ...               ...                  ...
# 17139           BR     179.127.39.84              unknown
# 17140           BR     179.127.39.84              unknown
# 17141           BR     179.127.39.84              unknown
# 17142           BR     179.127.39.84              unknown
# 17143           BR     179.127.39.84              unknown
#
#                               master_metadata_track_name  \
# 0                             Bitch Better Have My Money
# 1                                                Wannabe
# 2      Get Lucky (feat. Pharrell Williams and Nile Ro...
# 3                                              Bang Bang
# 4                                          Like a Prayer
# ...                                                  ...
# 17139                                      Ooo Baby Baby
# 17140                              Will I See You Again?
# 17141                              Easier Said Than Done
# 17142                                       Running Away
# 17143                                  Falling or flying
#
#       master_metadata_album_artist_name master_metadata_album_album_name  ...  \
# 0                               Rihanna       Bitch Better Have My Money  ...
# 1                           Spice Girls                            Spice  ...
# 2                             Daft Punk           Random Access Memories  ...
# 3                              Jessie J                     Sweet Talker  ...
# 4                               Madonna                      Celebration  ...
# ...                                 ...                              ...  ...
# 17139    Smokey Robinson & The Miracles                 Going To A Go-Go  ...
# 17140                 Thee Sacred Souls            Will I See You Again?  ...
# 17141                 Thee Sacred Souls                Thee Sacred Souls  ...
# 17142                 Thee Sacred Souls                     Running Away  ...
# 17143                       Jorja Smith                Falling or flying  ...
#
#       episode_name episode_show_name spotify_episode_uri reason_start  \
# 0             None              None                None     clickrow
# 1             None              None                None       fwdbtn
# 2             None              None                None       fwdbtn
# 3             None              None                None       fwdbtn
# 4             None              None                None       fwdbtn
# ...            ...               ...                 ...          ...
# 17139         None              None                None     clickrow
# 17140         None              None                None     clickrow
# 17141         None              None                None     clickrow
# 17142         None              None                None     clickrow
# 17143         None              None                None     clickrow
#
#       reason_end shuffle  skipped offline  offline_timestamp  incognito_mode
# 0         fwdbtn   False      NaN     0.0       1.573471e+12           False
# 1         fwdbtn   False      NaN     0.0       1.573471e+12           False
# 2         fwdbtn   False      NaN     0.0       1.573471e+12           False
# 3         fwdbtn   False      NaN     0.0       1.573471e+12           False
# 4         fwdbtn   False      NaN     0.0       1.573471e+12           False
# ...          ...     ...      ...     ...                ...             ...
# 17139    endplay   False     True     0.0       1.694482e+09           False
# 17140    endplay   False     True     0.0       1.694482e+09           False
# 17141    endplay   False     True     0.0       1.694482e+09           False
# 17142    endplay   False     True     0.0       1.694482e+09           False
# 17143    endplay   False     True     0.0       1.694482e+09           False
#
# [166053 rows x 21 columns]

# %%
pip3 install google-colab-shell
from google_colab_shell import shell
getshell()
# Out:
#   File "<ipython-input-88-544de59a17fc>", line 1
#     pip3 install google-colab-shell
#          ^
# SyntaxError: invalid syntax
